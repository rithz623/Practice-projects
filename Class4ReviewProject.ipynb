# %% [markdown]
# <a href="https://colab.research.google.com/github/rithz623/Practice-projects/blob/main/Class4ReviewProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
from google.colab import drive
drive.mount('content.drive')
# Out:
# Mounted at content.drive

# %%
car_sales = pd.read_csv("/content/content.drive/MyDrive/MLClass2024/car-sales-extended-missing-data.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0
# 5   Honda    Red        42652.0    4.0  23883.0
# 6  Toyota   Blue       163453.0    4.0   8473.0
# 7   Honda  White            NaN    4.0  20306.0
# 8     NaN  White       130538.0    4.0   9374.0
# 9   Honda   Blue        51029.0    4.0  26683.0

# %%
car_sales.tail(10)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 990  Toyota  White       173408.0    4.0   8082.0
# 991   Honda   Blue       235985.0    4.0   9184.0
# 992   Honda  Green        54721.0    4.0  27419.0
# 993  Nissan  Black       162523.0    4.0   4696.0
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0

# %%
car_sales.dtypes
# Out:
# Make              object
# Colour            object
# Odometer (KM)    float64
# Doors            float64
# Price            float64
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
print(car_sales.shape)
car_sales.dropna(axis=0, inplace=True)
print(car_sales.shape)
# Out:
# (1000, 5)
# (773, 5)

# %%
year_values = np.random.randint(2000, 2025, (773))

# %%
car_sales["Date Created"] = year_values

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Date Created
# 0     Honda  White        35431.0    4.0  15323.0          2009
# 1       BMW   Blue       192714.0    5.0  19943.0          2022
# 2     Honda  White        84714.0    4.0  28343.0          2021
# 3    Toyota  White       154365.0    4.0  13434.0          2014
# 4    Nissan   Blue       181577.0    3.0  14043.0          2003
# ..      ...    ...            ...    ...      ...           ...
# 994     BMW   Blue       163322.0    3.0  31666.0          2011
# 995  Toyota  Black        35820.0    4.0  32042.0          2016
# 997  Nissan   Blue        66604.0    4.0  31570.0          2023
# 998   Honda  White       215883.0    4.0   4001.0          2007
# 999  Toyota   Blue       248360.0    4.0  12732.0          2001
#
# [773 rows x 6 columns]

# %%
plt.style.available
plt.style.use("seaborn-v0_8-notebook")

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

# %%
fig.suptitle("Car Sales Data")
fig

# %%
ax1.set(xlabel="Odometer", ylabel="Doors", title="Odometer Values based on Doors")
ax2.set(xlabel="Odometer", ylabel="Price", title="Odometer Values Based on price")
fig

# %%
ax1.scatter(car_sales["Odometer (KM)"], car_sales["Doors"])
fig

# %%
ax2.scatter(car_sales["Odometer (KM)"], car_sales["Price"])
fig
